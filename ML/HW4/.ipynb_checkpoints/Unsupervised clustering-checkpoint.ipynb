# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import sparse
from tqdm import tqdm

from sklearn.cluster import KMeans
from sklearn.cluster import AgglomerativeClustering
from sklearn.cluster import DBSCAN
from sklearn.cluster import MiniBatchKMeans
import hdbscan 
from sklearn.mixture import GaussianMixture
from sklearn.cluster import SpectralClustering
from yellowbrick.cluster import KElbowVisualizer
from sklearn.metrics import silhouette_score

from sklearn.decomposition import TruncatedSVD
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import umap

from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MaxAbsScaler
from sklearn.preprocessing import RobustScaler

# %%
data = sparse.load_npz("train.npz")

# %% [markdown]
# **Пробую понять оптимальное колличество кластеров**

# %%
n = 30
dist = []
silhouette_scores = []

for k in tqdm(range(2, n)):
    model = KMeans(n_clusters=k)
    model.fit(data)
    
    dist.append(model.inertia_)

    silhouette_scores.append(silhouette_score(data, model.labels_))
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 28/28 [1:31:21<00:00, 195.78s/it]

# %%
plt.plot(range(2, n), dist)
plt.xlabel('Количество кластеров')
plt.ylabel('Дистанция')
plt.title('График метода локтя')
plt.grid(True)
plt.show()

# %%
plt.plot(range(2, n), silhouette_scores)
plt.xlabel('Количество кластеров')
plt.ylabel('Silhouette score')
plt.title('График silhouette score')
plt.grid(True)
plt.show()

# %%
model = KMeans(n_clusters=10)
visualizer = KElbowVisualizer(model, k=(3, 10), timings=False)
visualizer.fit(data)
visualizer.show()
plt.show()
# Out:
# C:\Users\baben_bakg1j1\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\baben_bakg1j1\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\baben_bakg1j1\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
# ...

# %%
def make_sub(labels):
    submission = pd.DataFrame({'ID':range(data.shape[0]), 'TARGET':labels})
    submission.to_csv('submission.csv', index=False)
    print(submission.head(3))

# %% [markdown]
# **KMeans**

# %%
model_data = KMeans(n_clusters=13)
model_data.fit(data)
# Out:
# KMeans(n_clusters=13)

# %%
make_sub(model_data.labels_)

# %% [markdown]
# **AgglomerativeClustering (очень долго обучается и показывает плохой результат)**

# %%
model_AC = AgglomerativeClustering(n_clusters=13, linkage='ward')
model_AC.fit(data.toarray())
# Out:
# AgglomerativeClustering(n_clusters=13)

# %%
make_sub(model_AC.labels_)
# Out:
#    ID  TARGET
# 0   0       0
# 1   1       6
# 2   2       1

# %% [markdown]
# **DBSCAN (лучший результат, eps=1.3425, min_samples=7)**

# %%
model_db = DBSCAN(eps=1.3425, min_samples=7)
model_db.fit(data)
# Out:
# DBSCAN(eps=1.3425, min_samples=7)

# %%
submission = pd.DataFrame({'ID':range(data.shape[0]), 'TARGET':model_db.labels_})
print(submission.query('TARGET == -1').TARGET.count())
submission.describe()
# Out:
# 4600
#                  ID        TARGET
# count  14590.000000  14590.000000
# mean    7294.500000     -0.306785
# std     4211.914549      0.516161
# min        0.000000     -1.000000
# 25%     3647.250000     -1.000000
# 50%     7294.500000      0.000000
# 75%    10941.750000      0.000000
# max    14589.000000      7.000000

# %%
make_sub(model_db.labels_)
# Out:
#    ID  TARGET
# 0   0      -1
# 1   1       0
# 2   2      -1

# %% [markdown]
# **HDBSCAN (min_cluster_size=3)**

# %%
model_hdb = hdbscan.HDBSCAN(min_cluster_size=3)
model_hdb.fit(data)
# Out:
# HDBSCAN(min_cluster_size=3)

# %%
submission = pd.DataFrame({'ID':range(data.shape[0]), 'TARGET':model_hdb.labels_})
print(submission.query('TARGET == -1').TARGET.count())
submission.describe()
# Out:
# 2791
#                  ID        TARGET
# count  14590.000000  14590.000000
# mean    7294.500000     -0.190884
# std     4211.914549      0.394057
# min        0.000000     -1.000000
# 25%     3647.250000      0.000000
# 50%     7294.500000      0.000000
# 75%    10941.750000      0.000000
# max    14589.000000      1.000000

# %%
make_sub(model_hdb.labels_)
# Out:
#    ID  TARGET
# 0   0       0
# 1   1       0
# 2   2      -1

# %% [markdown]
# **Gaussian Mixture (не получается работать с разрежнной матрицей)**

# %%
model_GM = GaussianMixture(n_components=5)
model_GM.fit(df)

# %% [markdown]
# **Spectral Clustering (n_clusters=10, eigen_solver='arpack')**

# %%
model_SC = SpectralClustering(n_clusters=10, eigen_solver='arpack', gamma=1.3425)
model_SC.fit(data)
# Out:
# SpectralClustering(eigen_solver='arpack', gamma=1.3425, n_clusters=10)

# %%
submission = pd.DataFrame({'ID':range(data.shape[0]), 'TARGET':model_SC.labels_})
print(submission.query('TARGET == -1').TARGET.count())
submission.describe()
# Out:
# 0
#                  ID        TARGET
# count  14590.000000  14590.000000
# mean    7294.500000      4.832899
# std     4211.914549      3.053688
# min        0.000000      0.000000
# 25%     3647.250000      2.000000
# 50%     7294.500000      4.000000
# 75%    10941.750000      8.000000
# max    14589.000000      9.000000

# %%
make_sub(model_SC.labels_)
# Out:
#    ID  TARGET
# 0   0       2
# 1   1       2
# 2   2       9

# %% [markdown]
# **Применение методов нормировки**

# %%
scaler = StandardScaler(with_mean=False)
data_scaled = scaler.fit_transform(data)

# %%
scaler = MaxAbsScaler()
data_scaled = scaler.fit_transform(data_scaled)

# %%
scaler = RobustScaler()
data_scaled = scaler.fit_transform(data_scaled)

# %% [markdown]
# **Применение методов понижения размерности**

# %%
data.shape
# Out:
# (14590, 77888)

# %%
svd = TruncatedSVD(n_components=1000)
data_scaled = svd.fit_transform(data)

# %%
model_TSNE = TSNE(n_components=3, perplexity=10, early_exaggeration=4.0, learning_rate=500.0, n_iter=2500, metric="cosine")
data_scaled = model_TSNE.fit_transform(data)
# Out:
# C:\Users\baben_bakg1j1\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\baben_bakg1j1\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:819: FutureWarning: 'square_distances' has been introduced in 0.24 to help phase out legacy squaring behavior. The 'legacy' setting will be removed in 1.1 (renaming of 0.26), and the default setting will be changed to True. In 1.3, 'square_distances' will be removed altogether, and distances will be squared by default. Set 'square_distances'=True to silence this warning.
#   warnings.warn(

# %%
reducer = umap.UMAP(
    n_components=100,
    n_neighbors=750,
    min_dist=0.075,
    spread=0.85,
    metric='jaccard',
    target_metric='manhattan',
    random_state=42,
    verbose=True
)
data_scaled = reducer.fit_transform(data)
# Out:
# C:\Users\baben_bakg1j1\anaconda3\lib\site-packages\umap\umap_.py:1880: UserWarning: gradient function is not yet implemented for jaccard distance metric; inverse_transform will be unavailable
#   warn(
# C:\Users\baben_bakg1j1\anaconda3\lib\site-packages\umap\umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# UMAP(angular_rp_forest=True, metric='jaccard', min_dist=0.075, n_components=100, n_jobs=1, n_neighbors=750, random_state=42, spread=0.85, target_metric='manhattan', verbose=True)
# Sat Apr 27 20:53:59 2024 Construct fuzzy simplicial set
# Sat Apr 27 20:53:59 2024 Finding Nearest Neighbors
# Sat Apr 27 20:53:59 2024 Building RP forest with 11 trees
# Sat Apr 27 20:54:04 2024 metric NN descent for 14 iterations
# 	 1  /  14
# 	 2  /  14
# 	 3  /  14
# 	 4  /  14
# 	 5  /  14
# 	 6  /  14
# 	 7  /  14
# ...

# %%
reducer = umap.UMAP(
    n_components=100,
    random_state=42,
    verbose=True
)
data_scaled = reducer.fit_transform(data)
# Out:
# C:\Users\baben_bakg1j1\anaconda3\lib\site-packages\umap\umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# UMAP(n_components=100, n_jobs=1, random_state=42, verbose=True)
# Sun Apr 28 23:47:22 2024 Construct fuzzy simplicial set
# Sun Apr 28 23:47:22 2024 Finding Nearest Neighbors
# Sun Apr 28 23:47:22 2024 Building RP forest with 11 trees
# Sun Apr 28 23:47:28 2024 metric NN descent for 14 iterations
# 	 1  /  14
# 	 2  /  14
# 	 3  /  14
# 	 4  /  14
# 	 5  /  14
# 	 6  /  14
# 	 7  /  14
# 	 8  /  14
# 	 9  /  14
# 	 10  /  14
# 	Stopping threshold met -- exiting after 10 iterations
# Sun Apr 28 23:48:06 2024 Finished Nearest Neighbor Search
# Sun Apr 28 23:48:06 2024 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# ...

# %%
model_KM = KMeans(n_clusters=5, random_state=13)
visualizer = KElbowVisualizer(model_KM, k=(2, 15), timings=False)
visualizer.fit(data_scaled)
visualizer.show()
plt.show()

# %% [markdown]
# **KMeans (n_clusters=4, n_components=100) (неплохо при (5,6500) (7,7000); (5,3))**

# %%
model_KM = KMeans(random_state=42, n_clusters=4, n_init=250, max_iter=500)
model_KM.fit(data_scaled)
make_sub(model_KM.labels_)
# Out:
#    ID  TARGET
# 0   0       3
# 1   1       2
# 2   2       2

# %%
submission = pd.DataFrame({'ID':range(data.shape[0]), 'TARGET':model_KM.labels_})
print(submission.query('TARGET == -1').TARGET.count())
print(submission.query('TARGET > 0')['TARGET'].count())
submission.describe()
# Out:
# 0
# 13783
#                  ID        TARGET
# count  14590.000000  14590.000000
# mean    7294.500000      1.744345
# std     4211.914549      0.915454
# min        0.000000      0.000000
# 25%     3647.250000      1.000000
# 50%     7294.500000      2.000000
# 75%    10941.750000      3.000000
# max    14589.000000      3.000000

# %% [markdown]
# **MiniBatchKMeans**

# %%
model_KMB = MiniBatchKMeans(n_clusters=10, random_state=0)
model_KMB.fit(data_scaled)
make_sub(model_KMB.labels_)
# Out:
#    ID  TARGET
# 0   0       8
# 1   1       4
# 2   2       0
# C:\Users\baben_bakg1j1\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1043: UserWarning: MiniBatchKMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can prevent it by setting batch_size >= 3072 or by setting the environment variable OMP_NUM_THREADS=4
#   warnings.warn(

# %% [markdown]
# **DBSCAN (стал хуже)**

# %%
model_db = DBSCAN(eps=1.2, min_samples=50)
model_db.fit(data_scaled)
submission = pd.DataFrame({'ID':range(data.shape[0]), 'TARGET':model_db.labels_})
print(submission.query('TARGET == -1').TARGET.count())
print(submission.query('TARGET > 0')['TARGET'].count())
submission.describe()
# Out:
# 1108
# 13173
#                  ID        TARGET
# count  14590.000000  14590.000000
# mean    7294.500000      3.384647
# std     4211.914549      1.597374
# min        0.000000     -1.000000
# 25%     3647.250000      3.000000
# 50%     7294.500000      4.000000
# 75%    10941.750000      4.000000
# max    14589.000000      5.000000

# %%
make_sub(model_db.labels_)
# Out:
#    ID  TARGET
# 0   0      -1
# 1   1      -1
# 2   2      -1

# %% [markdown]
# **Spectral Clustering (стал хуже)**

# %%
model_SC = SpectralClustering(n_clusters=4, eigen_solver='arpack')
model_SC.fit(data)
make_sub(model_SC.labels_)
# Out:
#    ID  TARGET
# 0   0       3
# 1   1       3
# 2   2       3
